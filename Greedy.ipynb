# %% [markdown]
# Simply Trying on Italy(Greedy algorithm)

# %%
import logging
from itertools import combinations
import pandas as pd
import numpy as np
from geopy.distance import geodesic
import networkx as nx
from icecream import ic

logging.basicConfig(level=logging.DEBUG)

# %%
#Read cities data and distance matrix

CITIES = pd.read_csv('cities/italy.csv', header=None, names=['name', 'lat', 'lon'])
DIST_MATRIX = np.zeros((len(CITIES), len(CITIES)))
for c1, c2 in combinations(CITIES.itertuples(), 2):
    DIST_MATRIX[c1.Index, c2.Index] = DIST_MATRIX[c2.Index, c1.Index] = geodesic(
        (c1.lat, c1.lon), (c2.lat, c2.lon)
    ).km
CITIES.head()
# Out:
#       name    lat    lon
# 0   Ancona  43.60  13.50
# 1   Andria  41.23  16.29
# 2     Bari  41.12  16.87
# 3  Bergamo  45.70   9.67
# 4  Bologna  44.50  11.34

# %%
#define cost
def tsp_cost(tsp):
    assert tsp[0] == tsp[-1]
    assert set(tsp) == set(range(len(CITIES)))

    tot_cost = 0
    for c1, c2 in zip(tsp, tsp[1:]):
        tot_cost += DIST_MATRIX[c1, c2]
    return tot_cost

# %%
# Greedy algorithm
def greedy_tsp():
    best_path = None
    min_cost = float('inf')

    # Iterate over all starting cities
    for start_city in range(len(CITIES)):
        visited = np.full(len(CITIES), False)
        dist = DIST_MATRIX.copy()
        city = start_city
        visited[city] = True
        tsp = [city]

        logging.info(f"Starting from {CITIES.at[start_city, 'name']}")

        # Choose the closest city that hasn't been visited at each step
        while not np.all(visited):
            dist[:, city] = np.inf  # Mark the current city as visited
            closest = np.argmin(dist[city])
            visited[closest] = True
            tsp.append(closest)
            logging.debug(
                f"Visited {CITIES.at[city, 'name']} -> Closest city: {CITIES.at[closest, 'name']} "
                f"Distance: {DIST_MATRIX[city, closest]:.2f} km"
            )
            city = closest

        # Close the loop 
        tsp.append(start_city)
        path_cost = tsp_cost(tsp)

        # Check if it's the best solution
        if path_cost < min_cost:
            min_cost = path_cost
            best_path = tsp
            logging.info(f"New best path starting from {CITIES.at[start_city, 'name']} "
                         f"with distance {min_cost:.2f} km")

        # Output the complete path for the current starting city
        logging.info(f"Path for starting city {CITIES.at[start_city, 'name']}: "
                     f"{' -> '.join([CITIES.at[i, 'name'] for i in tsp])}, "
                     f"Total distance: {path_cost:.2f} km")

    return best_path, min_cost

# %%
best_path, min_cost = greedy_tsp()
logging.info(f"best route: {[CITIES.at[i, 'name'] for i in best_path]}")
logging.info(f"shortest total distance: {min_cost:.2f} km")
# Out:
# INFO:root:Starting from Ancona
# INFO:root:New best path starting from Ancona with distance 4436.03 km
# INFO:root:Path for starting city Ancona: Ancona -> Rimini -> Forlì -> Ravenna -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Trieste -> Bolzano -> Trento -> Novara -> Turin -> Genoa -> Leghorn -> Prato -> Florence -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Pescara -> Ancona, Total distance: 4436.03 km
# INFO:root:Starting from Andria
# INFO:root:Path for starting city Andria: Andria -> Bari -> Taranto -> Foggia -> Salerno -> Naples -> Giugliano in Campania -> Latina -> Rome -> Terni -> Perugia -> Ancona -> Rimini -> Forlì -> Ravenna -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Trieste -> Bolzano -> Trento -> Novara -> Turin -> Genoa -> Leghorn -> Prato -> Florence -> Pescara -> Palermo -> Catania -> Syracuse -> Reggio di Calabria -> Messina -> Cagliari -> Sassari -> Andria, Total distance: 5193.69 km
# INFO:root:Starting from Bari
# INFO:root:Path for starting city Bari: Bari -> Andria -> Foggia -> Salerno -> Naples -> Giugliano in Campania -> Latina -> Rome -> Terni -> Perugia -> Ancona -> Rimini -> Forlì -> Ravenna -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Trieste -> Bolzano -> Trento -> Novara -> Turin -> Genoa -> Leghorn -> Prato -> Florence -> Pescara -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Bari, Total distance: 5015.50 km
# INFO:root:Starting from Bergamo
# INFO:root:Path for starting city Bergamo: Bergamo -> Monza -> Milan -> Novara -> Turin -> Genoa -> Piacenza -> Parma -> Reggio nell'Emilia -> Modena -> Bologna -> Ferrara -> Padua -> Vicenza -> Verona -> Brescia -> Trento -> Bolzano -> Venice -> Ravenna -> Forlì -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Leghorn -> Prato -> Florence -> Pescara -> Trieste -> Bergamo, Total distance: 4737.44 km
# INFO:root:Starting from Bologna
# INFO:root:Path for starting city Bologna: Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Ferrara -> Ravenna -> Forlì -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Leghorn -> Prato -> Florence -> Genoa -> Novara -> Turin -> Trento -> Bolzano -> Trieste -> Pescara -> Bologna, Total distance: 4857.08 km
# INFO:root:Starting from Bolzano
# INFO:root:Path for starting city Bolzano: Bolzano -> Trento -> Vicenza -> Padua -> Venice -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Ravenna -> Forlì -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Leghorn -> Prato -> Florence -> Genoa -> Novara -> Turin -> Trieste -> Pescara -> Bolzano, Total distance: 5164.96 km
# INFO:root:Starting from Brescia
# INFO:root:Path for starting city Brescia: Brescia -> Bergamo -> Monza -> Milan -> Novara -> Turin -> Genoa -> Piacenza -> Parma -> Reggio nell'Emilia -> Modena -> Bologna -> Ferrara -> Padua -> Vicenza -> Verona -> Trento -> Bolzano -> Venice -> Ravenna -> Forlì -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Leghorn -> Prato -> Florence -> Pescara -> Trieste -> Brescia, Total distance: 4660.15 km
# INFO:root:Starting from Cagliari
# INFO:root:Path for starting city Cagliari: Cagliari -> Sassari -> Leghorn -> Prato -> Florence -> Forlì -> Ravenna -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Pescara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Ferrara -> Trento -> Bolzano -> Trieste -> Novara -> Turin -> Genoa -> Cagliari, Total distance: 5254.72 km
# INFO:root:Starting from Catania
# INFO:root:Path for starting city Catania: Catania -> Syracuse -> Reggio di Calabria -> Messina -> Palermo -> Salerno -> Naples -> Giugliano in Campania -> Latina -> Rome -> Terni -> Perugia -> Ancona -> Rimini -> Forlì -> Ravenna -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Trieste -> Bolzano -> Trento -> Novara -> Turin -> Genoa -> Leghorn -> Prato -> Florence -> Pescara -> Foggia -> Andria -> Bari -> Taranto -> Cagliari -> Sassari -> Catania, Total distance: 5128.69 km
# INFO:root:Starting from Ferrara
# INFO:root:Path for starting city Ferrara: Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Ravenna -> Forlì -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Leghorn -> Prato -> Florence -> Genoa -> Novara -> Turin -> Trento -> Bolzano -> Trieste -> Pescara -> Ferrara, Total distance: 4872.88 km
# INFO:root:Starting from Florence
# INFO:root:Path for starting city Florence: Florence -> Prato -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Ferrara -> Ravenna -> Forlì -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Leghorn -> Genoa -> Novara -> Turin -> Trento -> Bolzano -> Trieste -> Pescara -> Florence, Total distance: 4760.19 km
# INFO:root:Starting from Foggia
# INFO:root:Path for starting city Foggia: Foggia -> Andria -> Bari -> Taranto -> Salerno -> Naples -> Giugliano in Campania -> Latina -> Rome -> Terni -> Perugia -> Ancona -> Rimini -> Forlì -> Ravenna -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Trieste -> Bolzano -> Trento -> Novara -> Turin -> Genoa -> Leghorn -> Prato -> Florence -> Pescara -> Palermo -> Catania -> Syracuse -> Reggio di Calabria -> Messina -> Cagliari -> Sassari -> Foggia, Total distance: 5122.18 km
# INFO:root:Starting from Forlì
# INFO:root:Path for starting city Forlì: Forlì -> Ravenna -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Leghorn -> Prato -> Florence -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Ferrara -> Trento -> Bolzano -> Trieste -> Pescara -> Genoa -> Novara -> Turin -> Forlì, Total distance: 5040.86 km
# INFO:root:Starting from Genoa
# INFO:root:Path for starting city Genoa: Genoa -> Piacenza -> Parma -> Reggio nell'Emilia -> Modena -> Bologna -> Ferrara -> Padua -> Vicenza -> Verona -> Brescia -> Bergamo -> Monza -> Milan -> Novara -> Turin -> Leghorn -> Prato -> Florence -> Forlì -> Ravenna -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Pescara -> Trieste -> Venice -> Trento -> Bolzano -> Genoa, Total distance: 4761.34 km
# INFO:root:Starting from Giugliano in Campania
# INFO:root:Path for starting city Giugliano in Campania: Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Latina -> Rome -> Terni -> Perugia -> Ancona -> Rimini -> Forlì -> Ravenna -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Trieste -> Bolzano -> Trento -> Novara -> Turin -> Genoa -> Leghorn -> Prato -> Florence -> Pescara -> Sassari -> Cagliari -> Giugliano in Campania, Total distance: 4898.63 km
# INFO:root:Starting from Latina
# INFO:root:Path for starting city Latina: Latina -> Rome -> Terni -> Perugia -> Ancona -> Rimini -> Forlì -> Ravenna -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Trieste -> Bolzano -> Trento -> Novara -> Turin -> Genoa -> Leghorn -> Prato -> Florence -> Pescara -> Foggia -> Andria -> Bari -> Taranto -> Salerno -> Naples -> Giugliano in Campania -> Palermo -> Catania -> Syracuse -> Reggio di Calabria -> Messina -> Cagliari -> Sassari -> Latina, Total distance: 4766.88 km
# INFO:root:Starting from Leghorn
# INFO:root:Path for starting city Leghorn: Leghorn -> Prato -> Florence -> Forlì -> Ravenna -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Genoa -> Piacenza -> Parma -> Reggio nell'Emilia -> Modena -> Bologna -> Ferrara -> Padua -> Vicenza -> Verona -> Brescia -> Bergamo -> Monza -> Milan -> Novara -> Turin -> Trento -> Bolzano -> Venice -> Trieste -> Pescara -> Leghorn, Total distance: 4749.58 km
# INFO:root:Starting from Messina
# INFO:root:Path for starting city Messina: Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Salerno -> Naples -> Giugliano in Campania -> Latina -> Rome -> Terni -> Perugia -> Ancona -> Rimini -> Forlì -> Ravenna -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Trieste -> Bolzano -> Trento -> Novara -> Turin -> Genoa -> Leghorn -> Prato -> Florence -> Pescara -> Foggia -> Andria -> Bari -> Taranto -> Cagliari -> Sassari -> Messina, Total distance: 5103.78 km
# INFO:root:Starting from Milan
# INFO:root:Path for starting city Milan: Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Genoa -> Novara -> Turin -> Leghorn -> Prato -> Florence -> Forlì -> Ravenna -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Pescara -> Trieste -> Bolzano -> Trento -> Milan, Total distance: 4734.77 km
# INFO:root:Starting from Modena
# INFO:root:Path for starting city Modena: Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Ferrara -> Bologna -> Forlì -> Ravenna -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Leghorn -> Prato -> Florence -> Genoa -> Novara -> Turin -> Trento -> Bolzano -> Trieste -> Pescara -> Modena, Total distance: 4898.17 km
# INFO:root:Starting from Monza
# INFO:root:Path for starting city Monza: Monza -> Milan -> Novara -> Turin -> Genoa -> Piacenza -> Parma -> Reggio nell'Emilia -> Modena -> Bologna -> Ferrara -> Padua -> Vicenza -> Verona -> Brescia -> Bergamo -> Trento -> Bolzano -> Venice -> Ravenna -> Forlì -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Leghorn -> Prato -> Florence -> Pescara -> Trieste -> Monza, Total distance: 4809.87 km
# INFO:root:Starting from Naples
# INFO:root:Path for starting city Naples: Naples -> Giugliano in Campania -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Latina -> Rome -> Terni -> Perugia -> Ancona -> Rimini -> Forlì -> Ravenna -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Trieste -> Bolzano -> Trento -> Novara -> Turin -> Genoa -> Leghorn -> Prato -> Florence -> Pescara -> Sassari -> Cagliari -> Naples, Total distance: 4911.71 km
# INFO:root:Starting from Novara
# INFO:root:Path for starting city Novara: Novara -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Genoa -> Turin -> Leghorn -> Prato -> Florence -> Forlì -> Ravenna -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Pescara -> Trieste -> Bolzano -> Trento -> Novara, Total distance: 4740.09 km
# INFO:root:Starting from Padua
# INFO:root:Path for starting city Padua: Padua -> Vicenza -> Verona -> Brescia -> Bergamo -> Monza -> Milan -> Novara -> Turin -> Genoa -> Piacenza -> Parma -> Reggio nell'Emilia -> Modena -> Bologna -> Ferrara -> Ravenna -> Forlì -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Leghorn -> Prato -> Florence -> Venice -> Trieste -> Bolzano -> Trento -> Pescara -> Padua, Total distance: 4857.08 km
# INFO:root:Starting from Palermo
# INFO:root:Path for starting city Palermo: Palermo -> Catania -> Syracuse -> Reggio di Calabria -> Messina -> Salerno -> Naples -> Giugliano in Campania -> Latina -> Rome -> Terni -> Perugia -> Ancona -> Rimini -> Forlì -> Ravenna -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Trieste -> Bolzano -> Trento -> Novara -> Turin -> Genoa -> Leghorn -> Prato -> Florence -> Pescara -> Foggia -> Andria -> Bari -> Taranto -> Cagliari -> Sassari -> Palermo, Total distance: 4915.04 km
# INFO:root:Starting from Parma
# INFO:root:Path for starting city Parma: Parma -> Reggio nell'Emilia -> Modena -> Bologna -> Ferrara -> Padua -> Vicenza -> Verona -> Brescia -> Bergamo -> Monza -> Milan -> Novara -> Turin -> Genoa -> Piacenza -> Trento -> Bolzano -> Venice -> Ravenna -> Forlì -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Leghorn -> Prato -> Florence -> Pescara -> Trieste -> Parma, Total distance: 4761.07 km
# INFO:root:Starting from Perugia
# INFO:root:Path for starting city Perugia: Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Leghorn -> Prato -> Florence -> Forlì -> Ravenna -> Rimini -> Ancona -> Pescara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Ferrara -> Trento -> Bolzano -> Trieste -> Novara -> Turin -> Genoa -> Perugia, Total distance: 4928.33 km
# INFO:root:Starting from Pescara
# INFO:root:Path for starting city Pescara: Pescara -> Terni -> Perugia -> Ancona -> Rimini -> Forlì -> Ravenna -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Trieste -> Bolzano -> Trento -> Novara -> Turin -> Genoa -> Leghorn -> Prato -> Florence -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Pescara, Total distance: 4568.87 km
# INFO:root:Starting from Piacenza
# INFO:root:Path for starting city Piacenza: Piacenza -> Parma -> Reggio nell'Emilia -> Modena -> Bologna -> Ferrara -> Padua -> Vicenza -> Verona -> Brescia -> Bergamo -> Monza -> Milan -> Novara -> Turin -> Genoa -> Leghorn -> Prato -> Florence -> Forlì -> Ravenna -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Pescara -> Trieste -> Venice -> Trento -> Bolzano -> Piacenza, Total distance: 4576.20 km
# INFO:root:Starting from Prato
# INFO:root:Path for starting city Prato: Prato -> Florence -> Leghorn -> Reggio nell'Emilia -> Modena -> Bologna -> Ferrara -> Padua -> Vicenza -> Verona -> Brescia -> Bergamo -> Monza -> Milan -> Novara -> Turin -> Genoa -> Piacenza -> Parma -> Forlì -> Ravenna -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Pescara -> Trieste -> Venice -> Trento -> Bolzano -> Prato, Total distance: 4788.68 km
# INFO:root:Starting from Ravenna
# INFO:root:Path for starting city Ravenna: Ravenna -> Forlì -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Leghorn -> Prato -> Florence -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Ferrara -> Trento -> Bolzano -> Trieste -> Pescara -> Genoa -> Novara -> Turin -> Ravenna, Total distance: 5046.40 km
# INFO:root:Starting from Reggio di Calabria
# INFO:root:Path for starting city Reggio di Calabria: Reggio di Calabria -> Messina -> Catania -> Syracuse -> Palermo -> Salerno -> Naples -> Giugliano in Campania -> Latina -> Rome -> Terni -> Perugia -> Ancona -> Rimini -> Forlì -> Ravenna -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Trieste -> Bolzano -> Trento -> Novara -> Turin -> Genoa -> Leghorn -> Prato -> Florence -> Pescara -> Foggia -> Andria -> Bari -> Taranto -> Cagliari -> Sassari -> Reggio di Calabria, Total distance: 5118.41 km
# INFO:root:Starting from Reggio nell'Emilia
# INFO:root:Path for starting city Reggio nell'Emilia: Reggio nell'Emilia -> Modena -> Bologna -> Ferrara -> Padua -> Vicenza -> Verona -> Brescia -> Bergamo -> Monza -> Milan -> Novara -> Turin -> Genoa -> Piacenza -> Parma -> Prato -> Florence -> Leghorn -> Forlì -> Ravenna -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Pescara -> Trieste -> Venice -> Trento -> Bolzano -> Reggio nell'Emilia, Total distance: 4699.06 km
# INFO:root:Starting from Rimini
# INFO:root:Path for starting city Rimini: Rimini -> Forlì -> Ravenna -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Trieste -> Bolzano -> Trento -> Novara -> Turin -> Genoa -> Leghorn -> Prato -> Florence -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Pescara -> Ancona -> Rimini, Total distance: 4436.03 km
# INFO:root:Starting from Rome
# INFO:root:Path for starting city Rome: Rome -> Latina -> Terni -> Perugia -> Ancona -> Rimini -> Forlì -> Ravenna -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Trieste -> Bolzano -> Trento -> Novara -> Turin -> Genoa -> Leghorn -> Prato -> Florence -> Pescara -> Foggia -> Andria -> Bari -> Taranto -> Salerno -> Naples -> Giugliano in Campania -> Palermo -> Catania -> Syracuse -> Reggio di Calabria -> Messina -> Cagliari -> Sassari -> Rome, Total distance: 4795.40 km
# INFO:root:Starting from Salerno
# INFO:root:Path for starting city Salerno: Salerno -> Naples -> Giugliano in Campania -> Latina -> Rome -> Terni -> Perugia -> Ancona -> Rimini -> Forlì -> Ravenna -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Trieste -> Bolzano -> Trento -> Novara -> Turin -> Genoa -> Leghorn -> Prato -> Florence -> Pescara -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Salerno, Total distance: 4628.35 km
# INFO:root:Starting from Sassari
# INFO:root:Path for starting city Sassari: Sassari -> Cagliari -> Palermo -> Catania -> Syracuse -> Reggio di Calabria -> Messina -> Salerno -> Naples -> Giugliano in Campania -> Latina -> Rome -> Terni -> Perugia -> Ancona -> Rimini -> Forlì -> Ravenna -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Trieste -> Bolzano -> Trento -> Novara -> Turin -> Genoa -> Leghorn -> Prato -> Florence -> Pescara -> Foggia -> Andria -> Bari -> Taranto -> Sassari, Total distance: 4825.29 km
# INFO:root:Starting from Syracuse
# INFO:root:Path for starting city Syracuse: Syracuse -> Catania -> Reggio di Calabria -> Messina -> Palermo -> Salerno -> Naples -> Giugliano in Campania -> Latina -> Rome -> Terni -> Perugia -> Ancona -> Rimini -> Forlì -> Ravenna -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Trieste -> Bolzano -> Trento -> Novara -> Turin -> Genoa -> Leghorn -> Prato -> Florence -> Pescara -> Foggia -> Andria -> Bari -> Taranto -> Cagliari -> Sassari -> Syracuse, Total distance: 5136.22 km
# INFO:root:Starting from Taranto
# INFO:root:Path for starting city Taranto: Taranto -> Bari -> Andria -> Foggia -> Salerno -> Naples -> Giugliano in Campania -> Latina -> Rome -> Terni -> Perugia -> Ancona -> Rimini -> Forlì -> Ravenna -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Trieste -> Bolzano -> Trento -> Novara -> Turin -> Genoa -> Leghorn -> Prato -> Florence -> Pescara -> Palermo -> Catania -> Syracuse -> Reggio di Calabria -> Messina -> Cagliari -> Sassari -> Taranto, Total distance: 5163.49 km
# INFO:root:Starting from Terni
# INFO:root:Path for starting city Terni: Terni -> Perugia -> Ancona -> Rimini -> Forlì -> Ravenna -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Trieste -> Bolzano -> Trento -> Novara -> Turin -> Genoa -> Leghorn -> Prato -> Florence -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Pescara -> Terni, Total distance: 4568.87 km
# INFO:root:Starting from Trento
# INFO:root:Path for starting city Trento: Trento -> Bolzano -> Vicenza -> Padua -> Venice -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Ravenna -> Forlì -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Leghorn -> Prato -> Florence -> Genoa -> Novara -> Turin -> Trieste -> Pescara -> Trento, Total distance: 5172.80 km
# INFO:root:Starting from Trieste
# INFO:root:Path for starting city Trieste: Trieste -> Venice -> Padua -> Vicenza -> Verona -> Brescia -> Bergamo -> Monza -> Milan -> Novara -> Turin -> Genoa -> Piacenza -> Parma -> Reggio nell'Emilia -> Modena -> Bologna -> Ferrara -> Ravenna -> Forlì -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Leghorn -> Prato -> Florence -> Trento -> Bolzano -> Pescara -> Trieste, Total distance: 4746.36 km
# INFO:root:Starting from Turin
# INFO:root:Path for starting city Turin: Turin -> Novara -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Vicenza -> Padua -> Venice -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Genoa -> Leghorn -> Prato -> Florence -> Forlì -> Ravenna -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Pescara -> Trieste -> Bolzano -> Trento -> Turin, Total distance: 4662.18 km
# INFO:root:Starting from Venice
# INFO:root:Path for starting city Venice: Venice -> Padua -> Vicenza -> Verona -> Brescia -> Bergamo -> Monza -> Milan -> Novara -> Turin -> Genoa -> Piacenza -> Parma -> Reggio nell'Emilia -> Modena -> Bologna -> Ferrara -> Ravenna -> Forlì -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Leghorn -> Prato -> Florence -> Trento -> Bolzano -> Trieste -> Pescara -> Venice, Total distance: 4700.59 km
# INFO:root:Starting from Verona
# INFO:root:Path for starting city Verona: Verona -> Vicenza -> Padua -> Venice -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Trento -> Bolzano -> Trieste -> Ravenna -> Forlì -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Leghorn -> Prato -> Florence -> Genoa -> Novara -> Turin -> Pescara -> Verona, Total distance: 5097.20 km
# INFO:root:Starting from Vicenza
# INFO:root:Path for starting city Vicenza: Vicenza -> Padua -> Venice -> Ferrara -> Bologna -> Modena -> Reggio nell'Emilia -> Parma -> Piacenza -> Milan -> Monza -> Bergamo -> Brescia -> Verona -> Trento -> Bolzano -> Trieste -> Ravenna -> Forlì -> Rimini -> Ancona -> Perugia -> Terni -> Rome -> Latina -> Giugliano in Campania -> Naples -> Salerno -> Foggia -> Andria -> Bari -> Taranto -> Messina -> Reggio di Calabria -> Catania -> Syracuse -> Palermo -> Cagliari -> Sassari -> Leghorn -> Prato -> Florence -> Genoa -> Novara -> Turin -> Pescara -> Vicenza, Total distance: 5078.93 km
# INFO:root:best route: ['Ancona', 'Rimini', 'Forlì', 'Ravenna', 'Ferrara', 'Bologna', 'Modena', "Reggio nell'Emilia", 'Parma', 'Piacenza', 'Milan', 'Monza', 'Bergamo', 'Brescia', 'Verona', 'Vicenza', 'Padua', 'Venice', 'Trieste', 'Bolzano', 'Trento', 'Novara', 'Turin', 'Genoa', 'Leghorn', 'Prato', 'Florence', 'Perugia', 'Terni', 'Rome', 'Latina', 'Giugliano in Campania', 'Naples', 'Salerno', 'Foggia', 'Andria', 'Bari', 'Taranto', 'Messina', 'Reggio di Calabria', 'Catania', 'Syracuse', 'Palermo', 'Cagliari', 'Sassari', 'Pescara', 'Ancona']
# INFO:root:shortest total distance: 4436.03 km
